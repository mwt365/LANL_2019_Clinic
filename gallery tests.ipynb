# %%
import cv2
from spectrogram import Spectrogram
import matplotlib.pyplot as plt
import numpy as np
import scipy

# %%
file = '/home/lanl/Documents/dig/GEN3CH_4_009.dig'

# %%
spec = Spectrogram(file)

# %%
# def markProbeDestruction(spec,sens = 10):
t,v,i = spec.slice([0,500e-6],[0,7500])

# %%
normy = spec.squash(dB=False) * 2000

# %%
axes = plt.gca()
pcm = axes.pcolormesh(
            t * 1e6,
            v,
            i)
# plt.plot(peaks)
axes.plot(spec.time * 1e6, normy,
                        'b-', alpha = 0.75)
axes.vlines(peaks,0,2500)
axes.set_ylim(top=7000)
axes.set_xlim(left=0,right=500)
# Out:
# (0, 500)

# %%
normy.shape

# %%
scipy.signal.find_peaks(normy,height=,distance=100)[0]

# %%
normy = spec.squash(dB=False) * 2000

# %%
normy[normy < 100] = 0

# %%
peaks = scipy.signal.find_peaks(normy,distance=100)[0]
