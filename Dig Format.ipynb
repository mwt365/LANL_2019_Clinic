# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import os
from digfile import DigFile

# %%
from matplotlib.gridspec import GridSpec

# %%
def checkout(filename, start_time:float=50e-6, num_points:int=1024):
    df = DigFile(f'../dig/{filename}')
    htext = df.header_text
    if df.bits == 8:
        print(htext)
        return 0
    gridspec = GridSpec(2, 2, bottom=0.3, wspace=0.15)
    fig = plt.figure(figsize=(12, 12))
    
    formats = ['<u2', '<i2', '>u2', '>i2']
    for n, form in enumerate(formats):
        ax = fig.add_subplot(gridspec[n])
        df.data_format = np.dtype(form)
        thumb = df.thumbnail()
        ax.plot(thumb['times'] * 1e6, thumb['peak_to_peak'])
        endy = "Big endian" if '>' in form else "Little endian"
        if n < 2:
            ax.set_title(f"{'Unsigned' if 'u' in form else 'Signed'}")
        else:
            ax.set_xlabel("$t (\\mu \mathrm{s})$")
        if n % 2 == 0:
            ax.set_ylabel(endy)
    ax.annotate(
        filename+"\n\n"+htext,
        xy=(0.25, 0.25), xycoords='figure fraction',
        xytext=(0.25, 0.25), textcoords='figure fraction',
        horizontalalignment='left',
        verticalalignment='top',
        usetex=False,
        size=11
    )

# %%
myiter = iter(sorted([x for x in os.listdir('../dig/') if x.endswith('.dig')]))

# %%
checkout(next(myiter))
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
checkout(next(myiter))
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
checkout(next(myiter))
# Out:
# P14FMT TEKTRONIX,DPO72304DX,B280049,CF:91.1CT FV:10.8.3 Build 3
# PUD =
# :WFMO:BYT_N 1;BIT_N 8;ENC BIN;BN_F RP;BYT_O LSB;WFI "Ch4, DC coupling, 200.0mV/d
#   iv, 200.0us/div, 100000000 points, Sample mode";NR_P 100000000;PT_F Y;XUN "s";
#   XIN 20.0000E-12;XZE 493.7688E-15;PT_O 10000000;YUN "V";YMU 8.0000E-3;YOF 128.0
#   000;YZE 0.0000;NR_FR 1
#                     009                 DPO4000 Version 03/12/14
# Thu Jun 28 12:06:03 2018
#
# 100000000
# 8
# 2.000000e-011
# -2.000000e-004
# 8.000000e-003
# -1.024000e+000
# 0

# %%
checkout(next(myiter))
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
checkout(next(myiter))
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
checkout(next(myiter))
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
checkout(next(myiter))
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
checkout(next(myiter))
# Out:
# Extract from GEN3CH_4_009.dig
# 0.0 to 4.9999999999999996e-05
#
#
#
#
#
#   2500001
# 8
# 2e-11
# 0.0
# 0.008
# -1.024
# 0

# %%
checkout(next(myiter))
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-16-5e2553c0ab5e> in <module>
# ----> 1 checkout(next(myiter))
#
# StopIteration:

# %%
df.__dict__
